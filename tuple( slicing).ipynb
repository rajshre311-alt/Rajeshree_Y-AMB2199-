# %% [markdown]
# SLICING
# AMB2114-LATHASHREE TC

# %%
t=(1,2,3,4,5)
print(t[-3])
print(t[3])
# Out:
# 3
# 4

# %%
print(t[1:2])
# Out:
# (2,)

# %%
print(t[1:4])
# Out:
# (2, 3, 4)

# %%
print(t[-3:-5])
# Out:
# ()

# %%
print(t[ : :4])
# Out:
# (1, 5)

# %%
print(t[-5:-3])
# Out:
# (1, 2)

# %%
print(t[ : :-1])
# Out:
# (5, 4, 3, 2, 1)

# %%
t[2]=20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-535064871.py in <cell line: 0>()
# ----> 1 t[2]=20
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1340723757.py in <cell line: 0>()
# ----> 1 t.append(2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.insert(2,3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1543296983.py in <cell line: 0>()
# ----> 1 t.insert(2,3)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
t.add(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3039773695.py in <cell line: 0>()
# ----> 1 t.add(5)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
del t[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3430130672.py in <cell line: 0>()
# ----> 1 del t[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t.extend(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2904017955.py in <cell line: 0>()
# ----> 1 t.extend(2)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
t=(1,2,3,4,5)
t1=list(t)
t1.append(6)
t=tuple(t1)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t=(1,2,3,4,5)
t1=list(t)
t1.insert(2,"zero")
t=tuple(t1)
print(t)
# Out:
# (1, 2, 'zero', 3, 4, 5)

# %%
t=(1,2,3,4,5)
t1=list(t)
del t1[2]
t=tuple(t1)
print(t)
# Out:
# (1, 2, 4, 5)

# %%
print(sum(t))
# Out:
# 12

# %%
print("average = ",sum(t)/len(t))
# Out:
# average =  3.0

# %%
print("average =",sum(t)//len(t))
# Out:
# average = 3

# %%
print (min(t))
# Out:
# 1

# %%
print(max(t))
# Out:
# 5

# %%
print(6 in t)
# Out:
# False

# %%
print( 2 not in t)
# Out:
# False

# %%
print ( 2 in t)
# Out:
# True

# %%
t1=(1,2,3,4)
t2=(6,7,8,9)
t3=t1+t2
print(t3)
t4=t1+t2+t3
print(t4)
# Out:
# (1, 2, 3, 4, 6, 7, 8, 9)
# (1, 2, 3, 4, 6, 7, 8, 9, 1, 2, 3, 4, 6, 7, 8, 9)

# %%
t3=t1[1:2]+t2[1:3]
print(t3)
# Out:
# (2, 7, 8)

# %%
t.index(1)
# Out:
# 0

# %%
t.index (8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1032907642.py in <cell line: 0>()
# ----> 1 t.index (8)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t=(1,2,3,4,4,5)
t.count(4)
# Out:
# 2

# %%
l1=[1,2,3,4]
print(id(l1))
l1.append(5)
print(id(l1))
# Out:
# 137740517766656
# 137740517766656

# %%
t=(1,2,3)
print(id(t))
t1=set(t)
t1.add(4)
t=tuple(t1)
print(id(t))
# Out:
# 137740505947776
# 137740529766688

# %%
l1={1,2,3,4}
print(id(l1))
l1.add(5)
print(id(l1))
# Out:
# 137740506506496
# 137740506506496

# %%
c={1:2,3:4}
print(id(c))
c[5]=6
print(id(c))
# Out:
# 137740517761472
# 137740517761472

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+10
y=x
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11654984
# 11654984

# %%
x=x+10
print(id(x))
print(id(y))
# Out:
# 11655304
# 11654664
